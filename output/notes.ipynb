// %% [markdown]
// # DSA and C++

// %% [markdown]
// ### Basic syntax and code

// %%
#include <iostream> // this is a header file
using namespace std;

int main(){
    cout << "Hello  World \n";
    cout << 4;
    cout << 3 + 3;
    return 0;
}

// %% [markdown]
// addition of two no

// %%
#include <iostream>
using namespace std;

int main(){
    int x,y;
    cout << "enter a number\n";
    cin >> x;
    cout << "\n";
    cout << "enter the second number\n";
    cin >> y;
    cout << "the sum is "
}
